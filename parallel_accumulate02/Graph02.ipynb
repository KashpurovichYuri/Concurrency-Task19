#         '0.092822', '0.093819', '0.093168', '0.093235', '0.094273',
#         '0.093696', '0.093722', '0.093962', '0.094138', '0.094208',
#         '0.094886', '0.094362', '0.094587', '0.094839', '0.095026',
#         '0.095311', '0.100184', '0.152076', '0.134727', '0.121528',
#         '0.093480', '0.094569', '0.095877', '0.096468', '0.096930',
#         '0.096409', '0.102489', '0.097273', '0.109720', '0.097511',
#         '0.096960', '0.096965', '0.097144', '0.097236', '0.096466',
#         '0.096847', '0.098301', '0.100218', '0.101071', '0.109654',
#         '0.104169', '0.105820', '0.106826', '0.109360', '0.106756',
#         '0.108786', '0.112812', '0.113154', '0.113487', '0.114735',
#         '0.115984', '0.117289', '0.118695', '0.120170', '0.122992',
#         '0.123198', '0.131204', '0.125857', '0.128135', '0.128988',
#         '0.130402', '0.131886', '0.133893', '0.138457', '0.136216',
#         '0.138289', '0.139004', '0.140615', '0.142166', '0.143878',
#         '0.146822', '0.146321', '0.148452', '0.150063', '0.152716',
#         '0.154450', '0.155045', '0.154862', '0.163351', '0.157695',
#         '0.161575', '0.160932', '0.165357', '0.164821', '0.180170',
#         '0.167643', '0.168861', '0.176778', '0.171140', '0.245349',
#         '0.185409', '0.175357', '0.183342', '0.178765', '0.203607',
#         '0.181435', '0.192889', '0.184737', '0.188284', '0.188500',
#         '0.188100', '0.189841', '0.191195', '0.191258', '0.193320',
#         '0.195218', '0.197662', '0.198676', '0.200101', '0.200573',
#         '0.216363', '0.227172', '0.214645', '0.246458', '0.343903',
#         '0.209266', '0.207635', '0.209426', '0.210337', '0.212004',
#         '0.213434', '0.216812', '0.217867', '0.221684', '0.225212',
#         '0.363040', '0.510126', '0.648775', '0.783911', '0.909282',
#         '1.046637', '1.193911', '1.329904', '1.478723', '7.095695',
#         '14.010637'], dtype='<U9'),
#  201)

# %% [markdown]
# # Graph

# %% [markdown]
# Font settings

# %%
def FontSettings():
    mpl.rcParams['font.fantasy'] = 'Arial', 'Times New Roman', 'Tahoma'
    mpl.rcParams['font.family'] = 'fantasy'
    mpl.rcParams.get('font.family')[0]
    mpl.rcParams.get('font.fantasy')[1]

# %% [markdown]
# Figsize settings

# %%
def FigsizeSettings():
    mpl.rcParams['figure.figsize'] = 18, 9

# %% [markdown]
# Axis settings

# %%
def AxisSettings(ax):
    # majorLocator = MultipleLocator(5)
    xaxminorLocator = AutoMinorLocator(n=10)
    yaxminorLocator = AutoMinorLocator(n=5)
    
    # OX
    xax = ax.get_xaxis()
    xlabels = xax.get_ticklabels()
    xlines = xax.get_ticklines()
    for label in xlabels:
        label.set_color('black')  # axis label color
        label.set_rotation(0)  # rotation of labels of divisions of the axis
        label.set_fontsize(18)  # font size of labels of divisions of the axis
    for line in xlines:
        line.set_color('black')  # set the color of the dividing line
        line.set_markersize(3.5)  # set the length of the dividing line
        line.set_markeredgewidth(0.75)  # set the thickness of the division line
    # xax.set_major_locator(majorLocator)
    xax.set_minor_locator(xaxminorLocator)
    xax.set_minor_formatter(NullFormatter())
    
    # OY
    yax = ax.get_yaxis()
    ylabels = yax.get_ticklabels()
    ylines = yax.get_ticklines()
    for label in ylabels:
        label.set_color('black')  # axis label color
        label.set_rotation(0)  # rotation of labels of divisions of the axis
        label.set_fontsize(18)  # font size of labels of divisions of the axis
    for line in ylines:
        line.set_color('black')  # set the color of the dividing line
        line.set_markersize(3.5)  # set the length of the dividing line
        line.set_markeredgewidth(0.75)  # set the thickness of the division line
    # yax.set_major_locator(majorLocator)
    yax.set_minor_locator(yaxminorLocator)
    yax.set_minor_formatter(NullFormatter())

# %% [markdown]
# Building graph

# %%
FontSettings()
FigsizeSettings()
fig, axis = plt.subplots()
AxisSettings(axis)

plt.scatter(N_log[:210], t_log[:210], color='green', zorder=5)

axis.set_xlabel(r'Log of Number of threads $N$, pieces', loc='right', size=30)
axis.set_ylabel(r'Log of Time $t$, c', loc='top', size=30)
axis.set_xlim(min(N_log[:210]), max(N_log[:210]))
axis.set_ylim(min(t_log[:210]), max(t_log[:210]))

for ax in fig.axes:
    ax.grid(visible=True, which='both', ls='--')

fig.savefig('log02f.png', dpi=300)

# %%
FontSettings()
FigsizeSettings()
fig, axis = plt.subplots()
AxisSettings(axis)

plt.scatter(N_lin[:210], t_lin[:210], color='green', zorder=5)

axis.set_xlabel(r'Number of threads $N$, pieces', loc='right', size=30)
axis.set_ylabel(r'Time $t$, c', loc='top', size=30)
axis.set_xlim(min(N_lin[:210]), max(N_lin[:210]))
axis.set_ylim(min(t_lin[:210]), max(t_lin[:210]))

for ax in fig.axes:
    ax.grid(visible=True, which='both', ls='--')

fig.savefig('lin02f.png', dpi=300)

# %%
FontSettings()
FigsizeSettings()
fig, axis = plt.subplots()
AxisSettings(axis)

plt.scatter(N_lin[:190], t_lin[:190], color='green', zorder=5)

axis.set_xlabel(r'Number of threads $N$, pieces', loc='right', size=30)
axis.set_ylabel(r'Time $t$, c', loc='top', size=30)
axis.set_xlim(min(N_lin[:190]), max(N_lin[:190]))
axis.set_ylim(min(t_lin[:190]), max(t_lin[:190]))

for ax in fig.axes:
    ax.grid(visible=True, which='both', ls='--')

fig.savefig('lin02_t190.png', dpi=300)

# %%
FontSettings()
FigsizeSettings()
fig, axis = plt.subplots()
AxisSettings(axis)

plt.scatter(N_lin[:100], t_lin[:100], color='green', zorder=5)

axis.set_xlabel(r'Number of threads $N$, pieces', loc='right', size=30)
axis.set_ylabel(r'Time $t$, c', loc='top', size=30)
axis.set_xlim(min(N_lin[:100]), max(N_lin[:100]))
axis.set_ylim(min(t_lin[:100]), max(t_lin[:100]))

for ax in fig.axes:
    ax.grid(visible=True, which='both', ls='--')

fig.savefig('lin02_t100.png', dpi=300)
